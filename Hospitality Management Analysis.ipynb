# %% [markdown]
# # **HOSPITALITY MANAGEMENT ANALYSIS**

# %% [markdown]
# This code **imports the pandas, matplotlib, plotly libraries**, enabling users to utilize their functions and methods within Python.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# This code is to read the required datasets for analysis

# %%
fact=pd.read_csv("/content/drive/MyDrive/hospital_dataset/fact_bookings.csv")
aggregate=pd.read_csv("/content/drive/MyDrive/hospital_dataset/fact_aggregated_bookings.csv")
room=pd.read_csv("/content/drive/MyDrive/hospital_dataset/dim_rooms.csv")
date=pd.read_csv("/content/drive/MyDrive/hospital_dataset/dim_date.csv")
hotel=pd.read_csv("/content/drive/MyDrive/hospital_dataset/dim_hotels.csv")

# %% [markdown]
# #**fact_booking csv file : Data Exploration Process**

# %% [markdown]
# The following code is used to **see the data structure** of the corresponding CSV file

# %%
fact.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# This displays the **number of rows and columns** available in fact_booking csv file

# %%
fact.shape
# Out:
# (134590, 12)

# %% [markdown]
# This displays the **information about the fact_booking.csv file**, including the range of entries, data types of each column, and the count of null values

# %%
fact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 12.3+ MB

# %% [markdown]
# **comprehensive description** of the fact_booking.csv file, including min, max, mean and standard deviation of the corresponding columns

# %%
fact.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# ### **Unique Method in fact_booking csv file**

# %% [markdown]
# displays the unique values in room_category column of the fact.booking csv file

# %%
fact.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %% [markdown]
# displays the unique values in booking_platform column of the fact.booking csv file

# %%
fact.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %% [markdown]
# displays the unique values in booking_status column of the fact.booking csv file

# %%
fact.booking_status.unique()
# Out:
# array(['Checked Out', 'Cancelled', 'No Show'], dtype=object)

# %% [markdown]
# ### **Value_Count Method in fact_booking csv file**

# %% [markdown]
# Count the **occurrences of each unique value** in the specified column.

# %%
fact.room_category.value_counts()
# Out:
# room_category
# RT2    49505
# RT1    38446
# RT3    30566
# RT4    16073
# Name: count, dtype: int64

# %%
fact.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
fact.booking_status.value_counts()
# Out:
# booking_status
# Checked Out    94411
# Cancelled      33420
# No Show         6759
# Name: count, dtype: int64

# %% [markdown]
# # **Data Visualizations in Python using value_counts() method**

# %% [markdown]
# visualizing the value counts in a **graphical format** with a **customized background color**

# %%
import matplotlib.pyplot as plt
fact.booking_platform.value_counts().plot(kind="barh",color=["purple","skyblue"])
plt.gca().set_facecolor("pink")
plt.title("Booking_platform")
# Out:
# Text(0.5, 1.0, 'Booking_platform')

# %% [markdown]
# The following code displays the graphical representaions in terms of using the **Plotly library**

# %%
booking=fact["booking_platform"].value_counts()
figure=px.bar(booking, x=booking.values, y=booking.index, orientation='h', color=booking.values)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# here we displays each category of the booking_platform in a graphical way using **bar chart**

# %%
fact.booking_status.value_counts().plot(kind="pie")
plt.title("Booking_status")
# Out:
# Text(0.5, 1.0, 'Booking_status')

# %% [markdown]
# here we displays each category of the booking_status in a graphical way using **pie chart**

# %%
fact.room_category.value_counts().plot(kind="bar",color=["green","yellow"])
plt.title("Room_category")
# Out:
# Text(0.5, 1.0, 'Room_category')

# %% [markdown]
# here we displays each category of the room_category in a graphical way using **bar chart**

# %%
fact.booking_platform.value_counts().plot(kind="bar",color=["red","purple","pink"])
plt.title("HOSPTALITY ANALYSIS")
plt.xlabel("room_category")
plt.ylabel("booking_platform")
plt.show()

# %% [markdown]
# here we displays the **datas in a grahical format in which both the x-axis and y-axis** varies with different columns

# %% [markdown]
# ###**Groupby Method in fact_booking csv file**

# %%
group=fact.groupby("booking_platform")
group.get_group("direct online").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 0    May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 4    May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 38  May012216558RT221        16558     25-04-22      1/5/2022      3/5/2022
# 57   May012216559RT18        16559     28-04-22      1/5/2022      3/5/2022
# 76   May012216559RT22        16559     28-04-22      1/5/2022      6/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 0        -3.0           RT1    direct online            1.0    Checked Out
# 4         4.0           RT1    direct online            5.0    Checked Out
# 38        2.0           RT2    direct online            5.0    Checked Out
# 57        1.0           RT1    direct online            NaN      Cancelled
# 76        2.0           RT2    direct online            3.0    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to group the booking_platform column based on **direct online** alone

# %%
group=fact.groupby("booking_platform")
group.get_group("makeyourtrip").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 10  May012216558RT111        16558     29-04-22      1/5/2022      7/5/2022
# 12  May012216558RT113        16558     26-04-22      1/5/2022      7/5/2022
# 20   May012216558RT23        16558    10/4/2022      1/5/2022      7/5/2022
# 28  May012216558RT211        16558     30-04-22      1/5/2022      7/5/2022
# 34  May012216558RT217        16558     29-04-22      1/5/2022      7/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 10        1.0           RT1     makeyourtrip            5.0    Checked Out
# 12        2.0           RT1     makeyourtrip            5.0    Checked Out
# 20        1.0           RT2     makeyourtrip            NaN    Checked Out
# 28        2.0           RT2     makeyourtrip            NaN      Cancelled
# 34        4.0           RT2     makeyourtrip            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to group the booking_platform column based on **makeyourtrip** alone

# %%
group=fact.groupby("booking_platform")
group.get_group("journey").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 15  May012216558RT116        16558     27-04-22      1/5/2022      3/5/2022
# 50   May012216559RT11        16559     28-04-22      1/5/2022      3/5/2022
# 61  May012216559RT112        16559    11/4/2022      1/5/2022      6/5/2022
# 65  May012216559RT116        16559     27-04-22      1/5/2022      6/5/2022
# 78   May012216559RT24        16559     26-04-22      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 15        4.0           RT1          journey            NaN    Checked Out
# 50        2.0           RT1          journey            3.0    Checked Out
# 61        1.0           RT1          journey            5.0    Checked Out
# 65        3.0           RT1          journey            NaN      Cancelled
# 78        1.0           RT2          journey            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to group the booking_platform column based on **journey** alone

# %%
group=fact.groupby("booking_platform")
group.get_group("tripster").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 8    May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
# 37  May012216558RT220        16558     27-04-22      1/5/2022      4/5/2022
# 48   May012216558RT42        16558     27-04-22      1/5/2022      2/5/2022
# 52   May012216559RT13        16559     27-04-22      1/5/2022      2/5/2022
# 55   May012216559RT16        16559    11/4/2022      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 8         2.0           RT1         tripster            NaN    Checked Out
# 37        2.0           RT2         tripster            NaN    Checked Out
# 48        1.0           RT4         tripster            NaN    Checked Out
# 52        1.0           RT1         tripster            NaN      Cancelled
# 55        2.0           RT1         tripster            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to group the booking_platform column based on **tripster** alone

# %%
group=fact.groupby("booking_platform")
group.get_group("others").head()
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 1   May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 3   May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 5   May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6   May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 9  May012216558RT110        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 3       -2.0           RT1           others            NaN      Cancelled
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 9        1.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to group the booking_platform column based on **others** alone

# %%
group1=fact.groupby("booking_status")
group1.get_group("No Show").head()
# Out:
#             booking_id  property_id booking_date check_in_date checkout_date  \
# 7     May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# 32   May012216558RT215        16558     29-04-22      1/5/2022      4/5/2022
# 67   May012216559RT118        16559     27-04-22      1/5/2022      3/5/2022
# 93   May012216559RT219        16559     29-04-22      1/5/2022      2/5/2022
# 101  May012216559RT227        16559     29-04-22      1/5/2022      3/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 7          2.0           RT1          logtrip            NaN        No Show
# 32         2.0           RT2   direct offline            NaN        No Show
# 67         2.0           RT1           others            NaN        No Show
# 93         3.0           RT2           others            NaN        No Show
# 101        2.0           RT2         tripster            NaN        No Show
#
#      revenue_generated  revenue_realized
# ...

# %%
group1=fact.groupby("booking_status")
group1.get_group("Checked Out").head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 8  May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 8        2.0           RT1         tripster            NaN    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
group1=fact.groupby("booking_status")
group1.get_group("Cancelled").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 1    May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 3    May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 6    May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 13  May012216558RT114        16558     30-04-22      1/5/2022      5/5/2022
# 21   May012216558RT24        16558     29-04-22      1/5/2022      3/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 1         2.0           RT1           others            NaN      Cancelled
# 3        -2.0           RT1           others            NaN      Cancelled
# 6         2.0           RT1           others            NaN      Cancelled
# 13        1.0           RT1          logtrip            NaN      Cancelled
# 21        3.0           RT2           others            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %%
group2=fact.groupby("room_category")
group2.get_group("RT1").head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
group2=fact.groupby("room_category")
group2.get_group("RT2").head()
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 18  May012216558RT21        16558     7/4/2022      1/5/2022      6/5/2022
# 19  May012216558RT22        16558     30-04-22      1/5/2022      3/5/2022
# 20  May012216558RT23        16558    10/4/2022      1/5/2022      7/5/2022
# 21  May012216558RT24        16558     29-04-22      1/5/2022      3/5/2022
# 22  May012216558RT25        16558     26-04-22      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 18        2.0           RT2           others            NaN    Checked Out
# 19        2.0           RT2           others            5.0    Checked Out
# 20        1.0           RT2     makeyourtrip            NaN    Checked Out
# 21        3.0           RT2           others            NaN      Cancelled
# 22        1.0           RT2   direct offline            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %%
group2=fact.groupby("room_category")
group2.get_group("RT3").head()
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 39  May012216558RT31        16558     27-04-22      1/5/2022      3/5/2022
# 40  May012216558RT32        16558     24-04-22      1/5/2022      6/5/2022
# 41  May012216558RT33        16558     26-04-22      1/5/2022      7/5/2022
# 42  May012216558RT34        16558     29-04-22      1/5/2022      2/5/2022
# 43  May012216558RT35        16558     29-04-22      1/5/2022      4/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 39        3.0           RT3           others            3.0    Checked Out
# 40        4.0           RT3     makeyourtrip            NaN    Checked Out
# 41        2.0           RT3     makeyourtrip            NaN    Checked Out
# 42        1.0           RT3           others            5.0    Checked Out
# 43        NaN           RT3           others            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %%
group2=fact.groupby("room_category")
group2.get_group("RT4").head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 47   May012216558RT41        16558     26-04-22      1/5/2022      3/5/2022
# 48   May012216558RT42        16558     27-04-22      1/5/2022      2/5/2022
# 49   May012216558RT43        16558     29-04-22      1/5/2022      4/5/2022
# 137  May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
# 138  May012216559RT42        16559    11/4/2022      1/5/2022      3/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 47         2.0           RT4          logtrip            NaN      Cancelled
# 48         1.0           RT4         tripster            NaN    Checked Out
# 49         2.0           RT4   direct offline            NaN      Cancelled
# 137        4.0           RT4           others            NaN    Checked Out
# 138        2.0           RT4   direct offline            NaN      Cancelled
#
#      revenue_generated  revenue_realized
# ...

# %% [markdown]
# #**fact_booking csv file : Data Cleaning Process**

# %% [markdown]
# **Cleaning the invalid guests**

# %%
fact_clean=fact[fact.no_guests>=0]
fact_clean.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# Here the no_guests column has **negative values** less than zero so we have to remove those negative values to **avoid the data errors**, remove the values **lesser than zero** and displays **only the positive values** alone according to the condition given

# %%
fact_clean.shape
# Out:
# (134578, 12)

# %% [markdown]
# This displays the **no of rows and columns after removing the negative values** in the no_guests column of the fact_booking file

# %% [markdown]
# ### **Outlier removal in revenue_generated column**

# %%
max,min=fact_clean.revenue_generated.min(),fact_clean.revenue_generated.max()
max,min
# Out:
# (6500, 28560000)

# %% [markdown]
# This displays the **minimum and maximum values** in the revenue_generated column of the fact_booking file

# %%
avg,std=fact_clean.revenue_generated.mean(),fact_clean.revenue_generated.std()
avg,std
# Out:
# (15378.036937686695, 93040.1549314641)

# %% [markdown]
# This displays the **mean and standard deviation** values in the revenue_generated column of the fact_booking file

# %%
fact_clean.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
fact_clean["revenue_generated"].describe()
# Out:
# count    1.345780e+05
# mean     1.537804e+04
# std      9.304015e+04
# min      6.500000e+03
# 25%      9.900000e+03
# 50%      1.350000e+04
# 75%      1.800000e+04
# max      2.856000e+07
# Name: revenue_generated, dtype: float64

# %% [markdown]
# The **complete describtion** of the revenue_generated column

# %%
higher_limit=avg + 3 * std
higher_limit
# Out:
# 294498.50173207896

# %% [markdown]
# This displays the **3 standard deviation value** of the revenue_generated column

# %%
lower_limit = avg - 3 * std
lower_limit
# Out:
# -263742.4278567056

# %% [markdown]
# As seen above our **maximum value of the revenue_generated column is 28560000** which **does not comes below our 3 standard seviation** which is **294498.5017** so in this data **we have ouliers to remove it** use the following code

# %%
outlier=fact_clean[fact_clean.revenue_generated>higher_limit]
outlier
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %% [markdown]
# After removing the ouliers the **orginal data** will be given below

# %%
original_data=fact_clean[fact_clean.revenue_generated<=higher_limit]
original_data.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# This displays the **rows and columns after removing the outliers**

# %%
original_data.shape
# Out:
# (134573, 12)

# %% [markdown]
# ### **Outliers removal in revenue_realized column**

# %%
max,min=fact_clean.revenue_realized.min(),fact_clean.revenue_realized.max()
max,min
# Out:
# (2600, 45220)

# %%
avg,std=fact_clean.revenue_realized.mean(),fact_clean.revenue_realized.std()
avg,std
# Out:
# (12696.01182214032, 6927.841640957275)

# %%
fact_clean["revenue_realized"].describe()
# Out:
# count    134578.000000
# mean      12696.011822
# std        6927.841641
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit=fact_clean.revenue_realized.mean() + 3 * fact_clean.revenue_realized.std()
higher_limit
# Out:
# 33479.53674501214

# %%
lower_limit=avg - 3 * std
lower_limit
# Out:
# -8087.513100731503

# %% [markdown]
# As seen above our **maximum value of the revenue_realized column is 45220** which **does not comes below our 3 standard deviation** which is **33479** so in this data **we have ouliers to remove** it use the following code

# %%
outliers=fact_clean[fact_clean.revenue_realized>=higher_limit]
outliers.head()
# Out:
#             booking_id  property_id booking_date check_in_date checkout_date  \
# 137   May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
# 139   May012216559RT43        16559     1/5/2022      1/5/2022      2/5/2022
# 143   May012216559RT47        16559     28-04-22      1/5/2022      3/5/2022
# 149  May012216559RT413        16559     24-04-22      1/5/2022      7/5/2022
# 222   May012216560RT45        16560     30-04-22      1/5/2022      3/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 137        4.0           RT4           others            NaN    Checked Out
# 139        6.0           RT4         tripster            3.0    Checked Out
# 143        3.0           RT4           others            5.0    Checked Out
# 149        5.0           RT4          logtrip            NaN    Checked Out
# 222        5.0           RT4           others            3.0    Checked Out
#
#      revenue_generated  revenue_realized
# ...

# %% [markdown]
# from the above dataframe oberservation the **outliers occurs** in the **room_category "RT4"** alone since this will be the **most luxuriant rooms** with higher cost, once **we remove the ouliers the RT4 category will be remove** completely so to avoid this we need to do **analysis only for the RT4 category of revenue_realized**

# %%
fact_clean[fact_clean.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# **The 3 Standard deviation of the RT4 category of revenue_realized**
#
# =>  mean + 3 * std

# %%
23439 + 3 * 9048
# Out:
# 50583

# %% [markdown]
# Here the **maximum value of the RT4 category is 45220** which **comes below the 3 standard deviation of RT4 catgory** of **revenu_realized 50583** so condition becomes **true** then there is **no need to remove the outliers** in this column

# %%
original_data=fact_clean[fact_clean.revenue_realized<=higher_limit]
original_data.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# This code is to check the outliers based on some other columns if there is no outliers present it will display the column names alone

# %%
fact_clean[fact_clean.booking_id=="May012216558RT213"]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %% [markdown]
# Here the booking_id which we given below has the outlier so it will tend to display the entrie data of the paticular booking_id

# %%
fact_clean[fact_clean.booking_id=="May012216560RT45"]
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 222  May012216560RT45        16560     30-04-22      1/5/2022      3/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 222        5.0           RT4           others            3.0    Checked Out
#
#      revenue_generated  revenue_realized
# 222              34580             34580

# %% [markdown]
# The **total number of dataframes** available in **fact_booking is 134576** in that **77899 rows** has the **null values** in the **ratings_given** column since the **count of null values is higher** so we should not remove those null values and also we should replace that with a **mean or median** ratings.

# %%
fact_clean.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77899
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# The following code is used to see the **structure of the fatc_aggregate_booking csv file**

# %% [markdown]
# #**fact_aggregate_booking file : Data Exploration Process**

# %%
aggregate.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
# This displays the **number of rows and columns** available in fact_aggregated_booking csv file

# %%
aggregate.shape
# Out:
# (9200, 5)

# %% [markdown]
# This displays the **information** about the aggregated_booking.csv file, including the range of entries, data types of each column, and the count of null values

# %%
aggregate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9198 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 359.5+ KB

# %% [markdown]
# **comprehensive description** of the aggregated_booking.csv file, including min, max, mean and standard deviation of the corresponding columns

# %%
aggregate.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %% [markdown]
# ### **Unique Method fact_aggregate_booking file**

# %% [markdown]
# displays the unique values in the room_category column of the aggregated_booking csv file

# %%
aggregate.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %% [markdown]
# ### **Value_Count Method fact_aggregate_booking file**

# %% [markdown]
# Count the occurrences of each unique value in the specified column.

# %%
aggregate.room_category.value_counts()
# Out:
# room_category
# RT1    2300
# RT2    2300
# RT3    2300
# RT4    2300
# Name: count, dtype: int64

# %% [markdown]
# visualizing the value counts in a graphical format with a customized background color

# %%
aggregate.room_category.value_counts().plot(kind="bar",color=["pink","blue"])
# Out:
# <Axes: xlabel='room_category'>

# %% [markdown]
# In the fact_aggregated_booking csv file each occurance count of the room_category remains the same so the bar chart are appeared in the same levels

# %% [markdown]
# ### **Groupby Method fact_aggregate_booking file**

# %% [markdown]
# This code is to group the room_category of the fact_aggregated_booking  based on each category

# %%
group=aggregate.groupby("room_category")
group.get_group("RT1").head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
group=aggregate.groupby("room_category")
group.get_group("RT2").head()
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 24        19562      1-May-22           RT2                   23      23.0
# 25        18563      1-May-22           RT2                   21      29.0
# 26        17561      1-May-22           RT2                   32      36.0
# 27        17558      1-May-22           RT2                   38      50.0
# 28        16562      1-May-22           RT2                   30      43.0

# %%
group=aggregate.groupby("room_category")
group.get_group("RT3").head()
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 49        19563      1-May-22           RT3                   20      29.0
# 51        19562      1-May-22           RT3                   25      29.0
# 52        19561      1-May-22           RT3                   23      29.0
# 53        18562      1-May-22           RT3                   28      29.0
# 54        17558      1-May-22           RT3                   21      27.0

# %%
group=aggregate.groupby("room_category")
group.get_group("RT4").head()
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 75        19559      1-May-22           RT4                    2       3.0
# 76        16562      1-May-22           RT4                    4       6.0
# 77        17558      1-May-22           RT4                    4       6.0
# 78        17562      1-May-22           RT4                    4       6.0
# 79        19563      1-May-22           RT4                    4       6.0

# %% [markdown]
# The following code will displays only the datas related to capacity 50 based on our requirements we can also change the capacity

# %%
group=aggregate.groupby("capacity")
new=group.get_group(50)
new.head()
# Out:
#      property_id check_in_date room_category  successful_bookings  capacity
# 27         17558      1-May-22           RT2                   38      50.0
# 128        17558      2-May-22           RT2                   27      50.0
# 229        17558      3-May-22           RT2                   26      50.0
# 328        17558      4-May-22           RT2                   27      50.0
# 428        17558      5-May-22           RT2                   29      50.0

# %% [markdown]
# Here we also wants to note that all the capacity "50" comes under the room_catgory "RT2"

# %%
aggregate.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %% [markdown]
# In the fact_aggregated_booking csv file we have only two null values

# %%
aggregate.fillna(aggregate.capacity.median()).head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
# As seen above the column capacity in fact_aggregate_booking has two null values to avoid the null values we should the median method to fill the null values

# %% [markdown]
# #**Data Transformation Process of fact_aggregate_booking CSV file**

# %% [markdown]
# # Creating **new column in fact_aggregated_booking** csv file

# %%
aggregate["occupied_per"]=aggregate["successful_bookings"]/aggregate["capacity"] * 100
aggregate.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupied_per
# 0     83.333333
# 1     93.333333
# 2     76.666667
# 3    157.894737
# 4     94.736842

# %% [markdown]
# This code describes the **percentage of the successful_booking out of capacity**

# %%
failure_per=1-aggregate["successful_bookings"]/aggregate["capacity"]
failure_per.head()
# Out:
# 0    0.166667
# 1    0.066667
# 2    0.233333
# 3   -0.578947
# 4    0.052632
# dtype: float64

# %%
aggregate["failure_per"]=failure_per*100
aggregate.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupied_per  failure_per
# 0     83.333333    16.666667
# 1     93.333333     6.666667
# 2     76.666667    23.333333
# 3    157.894737   -57.894737
# 4     94.736842     5.263158

# %% [markdown]
# While we calculate the **failure percentage** we tend to note that one **percentage** is in the **negative** terms

# %%
avg=aggregate.groupby("room_category")["occupied_per"].mean()
avg
# Out:
# room_category
# RT1    58.224216
# RT2    58.040234
# RT3    58.028291
# RT4    59.300161
# Name: occupied_per, dtype: float64

# %% [markdown]
# Here we can't understand that **three of the room category have the same average** so we need check it with the room category names if it is right or we need to check the category

# %% [markdown]
# #**Insight Generation from all the fact and dimension tables**

# %% [markdown]
# ## **Merging the CSV file based on the similar columns**

# %%
merge=pd.merge(room,aggregate,left_on="room_id",right_on="room_category")
merge.head()
# Out:
#   room_id room_class  property_id check_in_date room_category  \
# 0     RT1   Standard        16559      1-May-22           RT1
# 1     RT1   Standard        19562      1-May-22           RT1
# 2     RT1   Standard        19563      1-May-22           RT1
# 3     RT1   Standard        17558      1-May-22           RT1
# 4     RT1   Standard        16558      1-May-22           RT1
#
#    successful_bookings  capacity  occupied_per  failure_per
# 0                   25      30.0     83.333333    16.666667
# 1                   28      30.0     93.333333     6.666667
# 2                   23      30.0     76.666667    23.333333
# 3                   30      19.0    157.894737   -57.894737
# 4                   18      19.0     94.736842     5.263158

# %% [markdown]
# Here we tend to **merge** two csv file which is **fact_aggregated_booking** and **dim_room** based on the room_category in aggregated_booking and room_id in the room file

# %%
room.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# Getting the values of the **dim_room csv** file

# %%
merge.groupby("room_category")["room_class"].count()
# Out:
# room_category
# RT1    2300
# RT2    2300
# RT3    2300
# RT4    2300
# Name: room_class, dtype: int64

# %% [markdown]
# Here we **count the number of times each room_class** occurs based on the room_category

# %%
merge.groupby("room_class")["occupied_per"].mean()
# Out:
# room_class
# Elite           58.040234
# Premium         58.028291
# Presidential    59.300161
# Standard        58.224216
# Name: occupied_per, dtype: float64

# %% [markdown]
# **When we see the occupied percentage in both room_category as well as room_class wise both will be the same so that we consider the data set is absolutely right**

# %%
merge[merge.room_class=="Presidential"].occupied_per.mean()
# Out:
# 59.300161116197934

# %% [markdown]
# We can also find the **averge for the particular room_class** here we find the **presidential** room_class

# %%
max,min=merge.capacity.max(),merge.capacity.min()
max,min
# Out:
# (50.0, 3.0)

# %% [markdown]
# Here we find the **maximum and minimum values of the capacity** of each room categories

# %%
group_max=merge[merge.capacity==max][["room_category","capacity","room_class"]]
group_max.head()
# Out:
#      room_category  capacity room_class
# 2303           RT2      50.0      Elite
# 2328           RT2      50.0      Elite
# 2353           RT2      50.0      Elite
# 2378           RT2      50.0      Elite
# 2403           RT2      50.0      Elite

# %% [markdown]
# In these we see all the room_category and the room_class remains the same for the **maximum capacity**

# %%
group_min=merge[merge.capacity<max][["room_category","capacity","room_class"]]
group_min.head()
# Out:
#   room_category  capacity room_class
# 0           RT1      30.0   Standard
# 1           RT1      30.0   Standard
# 2           RT1      30.0   Standard
# 3           RT1      19.0   Standard
# 4           RT1      19.0   Standard

# %% [markdown]
# These are the **room_category and room_class lesser than the maximum capacity**

# %%
min_Occ,max_Occ=merge.occupied_per.min(),merge.occupied_per.max()
min_Occ,max_Occ
# Out:
# (21.052631578947366, 473.0769230769231)

# %% [markdown]
# In the same way we find the **maximum and minimum values of the Occupied percentage**

# %%
Occ_max=merge[merge.occupied_per==max_Occ][["room_category","occupied_per","room_class"]]
Occ_max
# Out:
#      room_category  occupied_per room_class
# 1558           RT1    473.076923   Standard

# %% [markdown]
# Here we know that the **highest Occupied percentage room category is RT1** which is "Standard"

# %%
Occ_min=merge[merge.occupied_per<max_Occ][["room_category","occupied_per","room_class"]]
Occ_min.head()
# Out:
#   room_category  occupied_per room_class
# 0           RT1     83.333333   Standard
# 1           RT1     93.333333   Standard
# 2           RT1     76.666667   Standard
# 3           RT1    157.894737   Standard
# 4           RT1     94.736842   Standard

# %%
merge_1=pd.merge(merge,hotel,on="property_id")
merge_1.head()
# Out:
#   room_id room_class  property_id check_in_date room_category  \
# 0     RT1   Standard        16559      1-May-22           RT1
# 1     RT1   Standard        16559      2-May-22           RT1
# 2     RT1   Standard        16559      3-May-22           RT1
# 3     RT1   Standard        16559      4-May-22           RT1
# 4     RT1   Standard        16559      5-May-22           RT1
#
#    successful_bookings  capacity  occupied_per  failure_per  property_name  \
# 0                   25      30.0     83.333333    16.666667  Atliq Exotica
# 1                   20      30.0     66.666667    33.333333  Atliq Exotica
# 2                   17      30.0     56.666667    43.333333  Atliq Exotica
# 3                   21      30.0     70.000000    30.000000  Atliq Exotica
# 4                   16      30.0     53.333333    46.666667  Atliq Exotica
#
#   category    city
# 0   Luxury  Mumbai
# 1   Luxury  Mumbai
# 2   Luxury  Mumbai
# 3   Luxury  Mumbai
# 4   Luxury  Mumbai

# %%
merge_1.groupby("city")["occupied_per"].mean()
# Out:
# city
# Bangalore    56.594061
# Delhi        61.606265
# Hyderabad    58.144464
# Mumbai       57.936449
# Name: occupied_per, dtype: float64

# %% [markdown]
# Here we find the average of the Occupied percentage based on the city of the dim_hotel csv file

# %%
merge_1.groupby("city").value_counts()
# Out:
# city       room_id  room_class    property_id  check_in_date  room_category  successful_bookings  capacity  occupied_per  failure_per  property_name  category
# Bangalore  RT1      Standard      19558        1-Jul-22       RT1            17                   40.0      42.500000     57.500000    Atliq Grands   Luxury      1
#                                                1-Jun-22       RT1            12                   40.0      30.000000     70.000000    Atliq Grands   Luxury      1
#            RT3      Premium       19562        29-Jul-22      RT3            15                   29.0      51.724138     48.275862    Atliq Bay      Luxury      1
#                                                27-Jul-22      RT3            14                   29.0      48.275862     51.724138    Atliq Bay      Luxury      1
#                                                27-Jun-22      RT3            15                   29.0      51.724138     48.275862    Atliq Bay      Luxury      1
# ...

# %%
group=merge_1.groupby(merge_1.city=="Mumbai").value_counts()
group
# Out:
# city   room_id  room_class    property_id  check_in_date  room_category  successful_bookings  capacity  occupied_per  failure_per  property_name  category  city
# False  RT1      Standard      16558        1-Jul-22       RT1            11                   19.0      57.894737     42.105263    Atliq Grands   Luxury    Delhi        1
#        RT4      Presidential  19562        28-May-22      RT4            14                   14.0      100.000000    0.000000     Atliq Bay      Luxury    Bangalore    1
#                                            26-May-22      RT4            8                    14.0      57.142857     42.857143    Atliq Bay      Luxury    Bangalore    1
#                                            27-Jul-22      RT4            6                    14.0      42.857143     57.142857    Atliq Bay      Luxury    Bangalore    1
# ...

# %%
merge_1.groupby("category")["occupied_per"].mean()
# Out:
# category
# Business    58.211565
# Luxury      58.503316
# Name: occupied_per, dtype: float64

# %% [markdown]
# The **average Occupied percentage of both the category** in dim_hotel csv file almost **remains the same**

# %%
merge_1.groupby("category")["room_category"].count()
# Out:
# category
# Business    3312
# Luxury      5888
# Name: room_category, dtype: int64

# %%
merge_1.groupby("category")["room_class"].count()
# Out:
# category
# Business    3312
# Luxury      5888
# Name: room_class, dtype: int64

# %% [markdown]
# When we see the count of the "room_category" that occurs in each of the category like luxury and business will remains the same when we see the count in terms of the "room_class"

# %%
group = merge_1.groupby(["category","room_class"])
result = group.get_group(("Business","Presidential"))
result.head()
# Out:
#      room_id    room_class  property_id check_in_date room_category  \
# 1012     RT4  Presidential        19563      1-May-22           RT4
# 1013     RT4  Presidential        19563      2-May-22           RT4
# 1014     RT4  Presidential        19563      3-May-22           RT4
# 1015     RT4  Presidential        19563      4-May-22           RT4
# 1016     RT4  Presidential        19563      5-May-22           RT4
#
#       successful_bookings  capacity  occupied_per  failure_per property_name  \
# 1012                    4       6.0     66.666667    33.333333  Atliq Palace
# 1013                    4       6.0     66.666667    33.333333  Atliq Palace
# 1014                    4       6.0     66.666667    33.333333  Atliq Palace
# 1015                    3       6.0     50.000000    50.000000  Atliq Palace
# 1016                    3       6.0     50.000000    50.000000  Atliq Palace
#
#       category       city
# 1012  Business  Bangalore
# 1013  Business  Bangalore
# ...

# %%
result[["category","room_class"]].head()
# Out:
#       category    room_class
# 1012  Business  Presidential
# 1013  Business  Presidential
# 1014  Business  Presidential
# 1015  Business  Presidential
# 1016  Business  Presidential

# %% [markdown]
# In this we can also **group two columns** at the same time by the specific category of each columns

# %%
merge_2=pd.merge(aggregate,date,left_on="check_in_date",right_on="date")
merge_2.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occupied_per  failure_per       date  mmm yy week no  day_type
# 0     51.724138    48.275862  10-May-22  May 22    W 20  weekeday
# 1     63.333333    36.666667  10-May-22  May 22    W 20  weekeday
# 2     60.000000    40.000000  10-May-22  May 22    W 20  weekeday
# 3     53.333333    46.666667  10-May-22  May 22    W 20  weekeday
# 4     57.894737    42.105263  10-May-22  May 22    W 20  weekeday

# %%
merge_2.groupby("day_type")["occupied_per"].mean()
# Out:
# day_type
# weekeday    50.903675
# weekend     72.393421
# Name: occupied_per, dtype: float64

# %% [markdown]
# This discribes the mean of the **day_type** in date_csv file in terms of the **Occupied percentage**

# %%
merge_2.groupby("day_type")["occupied_per"].mean().round(3)
# Out:
# day_type
# weekeday    50.904
# weekend     72.393
# Name: occupied_per, dtype: float64

# %% [markdown]
# Here the attribute round specifies the number of digits that should be placed after the decimal points

# %%
merge_2[merge_2.day_type=="weekend"]["successful_bookings"].count()
# Out:
# 1900

# %% [markdown]
# This describes the **count of the succesfull_bookings of th rooms in the weekend alone** weekend booking will be the more whn compared to the weekdays

# %%
group=merge_2.groupby("day_type")
group.get_group("weekeday")
group.head()
# Out:
#      property_id check_in_date room_category  successful_bookings  capacity  \
# 0          19563     10-May-22           RT3                   15      29.0
# 1          18560     10-May-22           RT1                   19      30.0
# 2          19562     10-May-22           RT1                   18      30.0
# 3          19563     10-May-22           RT1                   16      30.0
# 4          17558     10-May-22           RT1                   11      19.0
# 400        19563     14-May-22           RT3                   22      29.0
# 401        18560     14-May-22           RT1                   26      30.0
# 402        19562     14-May-22           RT1                   28      30.0
# 403        19563     14-May-22           RT1                   22      30.0
# 404        17558     14-May-22           RT1                   14      19.0
#
#      occupied_per  failure_per       date  mmm yy week no  day_type
# ...

# %% [markdown]
# By using the groupby method we tend to group only the weekeday alone in the day_type

# %%
merge_3=pd.merge(fact,date,left_on="check_in_date",right_on="date")
merge_3
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, date, mmm yy, week no, day_type]
# Index: []

# %% [markdown]
# Here we just make a try to **merge the fact_aggregate_booking** csv file with the **dim_date** file based on the **check_in_date** in booking and **date** column in date file but this **can't be done** because there is **no similarities** between check_in_date and date column

# %%
merge_4=pd.merge(fact_clean,room,left_on="room_category",right_on="room_id")
merge_4.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 2  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 4  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized room_id room_class
# ...

# %% [markdown]
# Here **before analysis we need to clean the data** in which the **no_guests has some negative values** that should be cleaned properly by **removing the negative values**

# %%
merge_4.groupby("room_class")["revenue_generated"].mean().round(2)
# Out:
# room_class
# Elite           13766.83
# Premium         18718.11
# Presidential    27465.46
# Standard         9744.28
# Name: revenue_generated, dtype: float64

# %%
merge_4.groupby("room_category")["revenue_generated"].mean().round(2)
# Out:
# room_category
# RT1     9744.28
# RT2    13766.83
# RT3    18718.11
# RT4    27465.46
# Name: revenue_generated, dtype: float64

# %% [markdown]
# When we find the **mean of revenue_generated** in terms of both room_class as well as room_category both of them will remains the same

# %%
merge_4.groupby("room_class")["revenue_realized"].mean().round(2)
# Out:
# room_class
# Elite           11317.55
# Premium         15120.36
# Presidential    23439.31
# Standard         8052.46
# Name: revenue_realized, dtype: float64

# %%
merge_4.groupby("booking_platform")["revenue_generated"].mean().round(2)
# Out:
# booking_platform
# direct offline    16868.50
# direct online     17736.51
# journey           14884.62
# logtrip           15488.58
# makeyourtrip      14926.99
# others            14946.93
# tripster          15027.47
# Name: revenue_generated, dtype: float64

# %%
merge_4.groupby("booking_platform")["revenue_realized"].mean().round(2)
# Out:
# booking_platform
# direct offline    12790.57
# direct online     12633.81
# journey           12648.82
# logtrip           12708.63
# makeyourtrip      12671.55
# others            12700.43
# tripster          12779.52
# Name: revenue_realized, dtype: float64

# %% [markdown]
# The above two code describes the **average of the booking_platform interms of revenue_generated and revenue_realized by using the mean() method**

# %%
merge_4.groupby("booking_status")["revenue_generated"].mean().round(1)
# Out:
# booking_status
# Cancelled      14959.9
# Checked Out    15562.8
# No Show        14864.3
# Name: revenue_generated, dtype: float64

# %%
merge_4.groupby("booking_status")["revenue_realized"].mean().round(1)
# Out:
# booking_status
# Cancelled       5960.1
# Checked Out    14925.2
# No Show        14864.3
# Name: revenue_realized, dtype: float64

# %% [markdown]
# The above two code describes the average of the booking_status interms of revenue_generated and revenue_realized by using the mean() method

# %%
max_rate,min_rate=merge_4.ratings_given.max(),merge_4.ratings_given.min()
max_rate,min_rate
# Out:
# (5.0, 1.0)

# %%
rating=merge_4[merge_4.ratings_given<max_rate][["ratings_given","room_class"]]
rating.head()
# Out:
#     ratings_given room_class
# 3             4.0   Standard
# 7             4.0   Standard
# 16            3.0   Standard
# 36            4.0   Standard
# 43            3.0   Standard

# %% [markdown]
# This describes **the room_class that has the rating less than the maximum**

# %%
rating=merge_4[merge_4.ratings_given==max_rate][["ratings_given","room_class","booking_platform"]]
rating.head()
# Out:
#     ratings_given room_class booking_platform
# 1             5.0   Standard          logtrip
# 2             5.0   Standard    direct online
# 8             5.0   Standard     makeyourtrip
# 9             5.0   Standard          logtrip
# 10            5.0   Standard     makeyourtrip

# %% [markdown]
# This describes the **room_class which is standard that has the rating which is maximum**

# %%
merge_4[merge_4.booking_status=="Checked Out"]["booking_platform"].count()
# Out:
# 94403

# %% [markdown]
# Here based on the booking_platform this describes the **count of the checked Out booking_status**

# %%
merge_4[merge_4.booking_status=="Cancelled"]["booking_platform"].count()
# Out:
# 33417

# %%
merge_4[merge_4.booking_status=="No Show"]["booking_platform"].count()
# Out:
# 6758

# %% [markdown]
# The number of rows in both the calculation matches each other

# %%
94403+33417+6758
# Out:
# 134578

# %%
merge_4.shape
# Out:
# (134578, 14)

# %%
merge_5=pd.merge(fact_clean,hotel,on="property_id")
merge_5.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 2  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 3  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 4  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1          logtrip            5.0    Checked Out
# 2        4.0           RT1    direct online            5.0    Checked Out
# 3        2.0           RT1           others            4.0    Checked Out
# 4        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
merge_5.groupby("category")["revenue_generated"].mean().round(2)
# Out:
# category
# Business    15161.73
# Luxury      15509.73
# Name: revenue_generated, dtype: float64

# %%
merge_5.groupby("category")["revenue_realized"].mean().round(2)
# Out:
# category
# Business    12880.28
# Luxury      12583.82
# Name: revenue_realized, dtype: float64

# %% [markdown]
# This describes the average of the category in dim_hotel csv file in terms of revenue_generated and revenue_realized in fact_booking csv file when we see the average they are almost nearly closer to each other in both

# %% [markdown]
# ## **Some Tricky Exercises in our Project**

# %% [markdown]
# ## Exercise 1 : Find out unique property ids in aggregate bookings dataset

# %%
aggregate.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %% [markdown]
# ## Exercise 2 : Find out days on which bookings are greater than capacity

# %%
records=aggregate[aggregate.successful_bookings>aggregate.capacity]
records.check_in_date
# Out:
# 3        1-May-22
# 12       1-May-22
# 4136    11-Jun-22
# 6209     2-Jul-22
# 8522    25-Jul-22
# 9194    31-Jul-22
# Name: check_in_date, dtype: object

# %% [markdown]
# ## Exercise 3 : Find out properties that have highest capacity

# %%
max=aggregate.capacity.max()
high=aggregate.groupby("property_id")["capacity"].max()
high
# Out:
# property_id
# 16558    22.0
# 16559    41.0
# 16560    34.0
# 16561    24.0
# 16562    43.0
# 16563    41.0
# 17558    50.0
# 17559    39.0
# 17560    45.0
# 17561    36.0
# 17562    30.0
# 17563    44.0
# 17564    40.0
# 18558    30.0
# 18559    44.0
# 18560    40.0
# 18561    40.0
# 18562    38.0
# 18563    29.0
# 19558    40.0
# 19559    41.0
# 19560    38.0
# 19561    45.0
# 19562    30.0
# 19563    45.0
# Name: capacity, dtype: float64

# %% [markdown]
# ## Exercise 4 : In aggregate bookings find columns that have null values. Fill these null values with whatever you think is the appropriate subtitute (possible ways is to use mean or median)

# %%
aggregate.fillna(aggregate.capacity.median())
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %% [markdown]
# ## Exercise 5 : In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records

# %%
records=aggregate[aggregate.successful_bookings>aggregate.capacity]
records
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0
